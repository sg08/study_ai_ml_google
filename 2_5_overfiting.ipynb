# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/My Drive/DNN_code_colab_lesson_1_2')
sys.path.append('/content/drive/My Drive/DNN_code_colab_lesson_1_2/lesson_2')

# %% [markdown]
# # overfiting

# %%
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from multi_layer_net import MultiLayerNet
from common import optimizer


(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)
optimizer = optimizer.SGD(learning_rate=0.01)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.20333333333333334
#                 : 10. 正答率(テスト) = 0.1712
# Generation: 20. 正答率(トレーニング) = 0.30666666666666664
#                 : 20. 正答率(テスト) = 0.2266
# Generation: 30. 正答率(トレーニング) = 0.36
#                 : 30. 正答率(テスト) = 0.2665
# Generation: 40. 正答率(トレーニング) = 0.45666666666666667
#                 : 40. 正答率(テスト) = 0.3263
# Generation: 50. 正答率(トレーニング) = 0.56
#                 : 50. 正答率(テスト) = 0.3942
# Generation: 60. 正答率(トレーニング) = 0.6566666666666666
#                 : 60. 正答率(テスト) = 0.4603
# Generation: 70. 正答率(トレーニング) = 0.7066666666666667
#                 : 70. 正答率(テスト) = 0.5009
# Generation: 80. 正答率(トレーニング) = 0.7633333333333333
#                 : 80. 正答率(テスト) = 0.5392
# Generation: 90. 正答率(トレーニング) = 0.8
#                 : 90. 正答率(テスト) = 0.5825
# Generation: 100. 正答率(トレーニング) = 0.8066666666666666
#                 : 100. 正答率(テスト) = 0.5981
# Generation: 110. 正答率(トレーニング) = 0.8366666666666667
#                 : 110. 正答率(テスト) = 0.6176
# Generation: 120. 正答率(トレーニング) = 0.8333333333333334
#                 : 120. 正答率(テスト) = 0.6164
# Generation: 130. 正答率(トレーニング) = 0.8433333333333334
#                 : 130. 正答率(テスト) = 0.6409
# Generation: 140. 正答率(トレーニング) = 0.8733333333333333
#                 : 140. 正答率(テスト) = 0.6731
# Generation: 150. 正答率(トレーニング) = 0.9
#                 : 150. 正答率(テスト) = 0.6673
# Generation: 160. 正答率(トレーニング) = 0.9
#                 : 160. 正答率(テスト) = 0.6925
# Generation: 170. 正答率(トレーニング) = 0.9366666666666666
#                 : 170. 正答率(テスト) = 0.698
# Generation: 180. 正答率(トレーニング) = 0.93
#                 : 180. 正答率(テスト) = 0.708
# Generation: 190. 正答率(トレーニング) = 0.95
#                 : 190. 正答率(テスト) = 0.7119
# Generation: 200. 正答率(トレーニング) = 0.9666666666666667
#                 : 200. 正答率(テスト) = 0.7197
# Generation: 210. 正答率(トレーニング) = 0.9666666666666667
#                 : 210. 正答率(テスト) = 0.7123
# Generation: 220. 正答率(トレーニング) = 0.96
#                 : 220. 正答率(テスト) = 0.7165
# Generation: 230. 正答率(トレーニング) = 0.9766666666666667
#                 : 230. 正答率(テスト) = 0.7242
# Generation: 240. 正答率(トレーニング) = 0.9833333333333333
#                 : 240. 正答率(テスト) = 0.7268
# Generation: 250. 正答率(トレーニング) = 0.98
#                 : 250. 正答率(テスト) = 0.7407
# Generation: 260. 正答率(トレーニング) = 0.9866666666666667
#                 : 260. 正答率(テスト) = 0.7266
# Generation: 270. 正答率(トレーニング) = 0.9866666666666667
#                 : 270. 正答率(テスト) = 0.7361
# Generation: 280. 正答率(トレーニング) = 0.99
#                 : 280. 正答率(テスト) = 0.7516
# Generation: 290. 正答率(トレーニング) = 0.99
#                 : 290. 正答率(テスト) = 0.7496
# Generation: 300. 正答率(トレーニング) = 0.9933333333333333
#                 : 300. 正答率(テスト) = 0.7473
# Generation: 310. 正答率(トレーニング) = 0.9933333333333333
#                 : 310. 正答率(テスト) = 0.7513
# Generation: 320. 正答率(トレーニング) = 0.9933333333333333
#                 : 320. 正答率(テスト) = 0.7525
# Generation: 330. 正答率(トレーニング) = 0.9933333333333333
#                 : 330. 正答率(テスト) = 0.7458
# Generation: 340. 正答率(トレーニング) = 0.9933333333333333
#                 : 340. 正答率(テスト) = 0.7515
# Generation: 350. 正答率(トレーニング) = 0.9933333333333333
#                 : 350. 正答率(テスト) = 0.7569
# Generation: 360. 正答率(トレーニング) = 0.9933333333333333
#                 : 360. 正答率(テスト) = 0.7547
# Generation: 370. 正答率(トレーニング) = 0.9933333333333333
#                 : 370. 正答率(テスト) = 0.7586
# Generation: 380. 正答率(トレーニング) = 0.9933333333333333
#                 : 380. 正答率(テスト) = 0.7513
# Generation: 390. 正答率(トレーニング) = 0.9933333333333333
#                 : 390. 正答率(テスト) = 0.759
# Generation: 400. 正答率(トレーニング) = 0.9966666666666667
#                 : 400. 正答率(テスト) = 0.7578
# Generation: 410. 正答率(トレーニング) = 1.0
#                 : 410. 正答率(テスト) = 0.76
# Generation: 420. 正答率(トレーニング) = 1.0
#                 : 420. 正答率(テスト) = 0.7574
# Generation: 430. 正答率(トレーニング) = 1.0
#                 : 430. 正答率(テスト) = 0.7564
# Generation: 440. 正答率(トレーニング) = 1.0
#                 : 440. 正答率(テスト) = 0.7609
# Generation: 450. 正答率(トレーニング) = 1.0
#                 : 450. 正答率(テスト) = 0.7608
# Generation: 460. 正答率(トレーニング) = 1.0
#                 : 460. 正答率(テスト) = 0.7603
# Generation: 470. 正答率(トレーニング) = 1.0
#                 : 470. 正答率(テスト) = 0.7596
# Generation: 480. 正答率(トレーニング) = 1.0
#                 : 480. 正答率(テスト) = 0.7608
# Generation: 490. 正答率(トレーニング) = 1.0
#                 : 490. 正答率(テスト) = 0.7616
# Generation: 500. 正答率(トレーニング) = 1.0
#                 : 500. 正答率(テスト) = 0.7636
# Generation: 510. 正答率(トレーニング) = 1.0
#                 : 510. 正答率(テスト) = 0.7628
# Generation: 520. 正答率(トレーニング) = 1.0
#                 : 520. 正答率(テスト) = 0.7618
# Generation: 530. 正答率(トレーニング) = 1.0
#                 : 530. 正答率(テスト) = 0.7644
# Generation: 540. 正答率(トレーニング) = 1.0
#                 : 540. 正答率(テスト) = 0.7639
# Generation: 550. 正答率(トレーニング) = 1.0
#                 : 550. 正答率(テスト) = 0.7618
# Generation: 560. 正答率(トレーニング) = 1.0
#                 : 560. 正答率(テスト) = 0.7635
# Generation: 570. 正答率(トレーニング) = 1.0
#                 : 570. 正答率(テスト) = 0.7644
# Generation: 580. 正答率(トレーニング) = 1.0
#                 : 580. 正答率(テスト) = 0.7633
# Generation: 590. 正答率(トレーニング) = 1.0
#                 : 590. 正答率(テスト) = 0.7658
# Generation: 600. 正答率(トレーニング) = 1.0
#                 : 600. 正答率(テスト) = 0.7616
# Generation: 610. 正答率(トレーニング) = 1.0
#                 : 610. 正答率(テスト) = 0.7657
# Generation: 620. 正答率(トレーニング) = 1.0
#                 : 620. 正答率(テスト) = 0.7657
# Generation: 630. 正答率(トレーニング) = 1.0
#                 : 630. 正答率(テスト) = 0.7639
# Generation: 640. 正答率(トレーニング) = 1.0
#                 : 640. 正答率(テスト) = 0.7656
# Generation: 650. 正答率(トレーニング) = 1.0
#                 : 650. 正答率(テスト) = 0.7678
# Generation: 660. 正答率(トレーニング) = 1.0
#                 : 660. 正答率(テスト) = 0.7665
# Generation: 670. 正答率(トレーニング) = 1.0
#                 : 670. 正答率(テスト) = 0.7678
# Generation: 680. 正答率(トレーニング) = 1.0
#                 : 680. 正答率(テスト) = 0.7674
# Generation: 690. 正答率(トレーニング) = 1.0
#                 : 690. 正答率(テスト) = 0.7658
# Generation: 700. 正答率(トレーニング) = 1.0
#                 : 700. 正答率(テスト) = 0.7667
# Generation: 710. 正答率(トレーニング) = 1.0
#                 : 710. 正答率(テスト) = 0.7675
# Generation: 720. 正答率(トレーニング) = 1.0
#                 : 720. 正答率(テスト) = 0.7665
# Generation: 730. 正答率(トレーニング) = 1.0
#                 : 730. 正答率(テスト) = 0.7681
# Generation: 740. 正答率(トレーニング) = 1.0
#                 : 740. 正答率(テスト) = 0.7656
# Generation: 750. 正答率(トレーニング) = 1.0
#                 : 750. 正答率(テスト) = 0.767
# Generation: 760. 正答率(トレーニング) = 1.0
#                 : 760. 正答率(テスト) = 0.7675
# Generation: 770. 正答率(トレーニング) = 1.0
#                 : 770. 正答率(テスト) = 0.7681
# Generation: 780. 正答率(トレーニング) = 1.0
#                 : 780. 正答率(テスト) = 0.7675
# Generation: 790. 正答率(トレーニング) = 1.0
#                 : 790. 正答率(テスト) = 0.7693
# Generation: 800. 正答率(トレーニング) = 1.0
#                 : 800. 正答率(テスト) = 0.7662
# Generation: 810. 正答率(トレーニング) = 1.0
#                 : 810. 正答率(テスト) = 0.7685
# Generation: 820. 正答率(トレーニング) = 1.0
#                 : 820. 正答率(テスト) = 0.7679
# Generation: 830. 正答率(トレーニング) = 1.0
#                 : 830. 正答率(テスト) = 0.7683
# Generation: 840. 正答率(トレーニング) = 1.0
#                 : 840. 正答率(テスト) = 0.7691
# Generation: 850. 正答率(トレーニング) = 1.0
#                 : 850. 正答率(テスト) = 0.7684
# Generation: 860. 正答率(トレーニング) = 1.0
#                 : 860. 正答率(テスト) = 0.7693
# Generation: 870. 正答率(トレーニング) = 1.0
#                 : 870. 正答率(テスト) = 0.7692
# Generation: 880. 正答率(トレーニング) = 1.0
#                 : 880. 正答率(テスト) = 0.7691
# Generation: 890. 正答率(トレーニング) = 1.0
#                 : 890. 正答率(テスト) = 0.7696
# Generation: 900. 正答率(トレーニング) = 1.0
#                 : 900. 正答率(テスト) = 0.769
# Generation: 910. 正答率(トレーニング) = 1.0
#                 : 910. 正答率(テスト) = 0.768
# Generation: 920. 正答率(トレーニング) = 1.0
#                 : 920. 正答率(テスト) = 0.7689
# Generation: 930. 正答率(トレーニング) = 1.0
#                 : 930. 正答率(テスト) = 0.7678
# Generation: 940. 正答率(トレーニング) = 1.0
#                 : 940. 正答率(テスト) = 0.7688
# Generation: 950. 正答率(トレーニング) = 1.0
#                 : 950. 正答率(テスト) = 0.7681
# Generation: 960. 正答率(トレーニング) = 1.0
#                 : 960. 正答率(テスト) = 0.7702
# Generation: 970. 正答率(トレーニング) = 1.0
#                 : 970. 正答率(テスト) = 0.7701
# Generation: 980. 正答率(トレーニング) = 1.0
#                 : 980. 正答率(テスト) = 0.7703
# Generation: 990. 正答率(トレーニング) = 1.0
#                 : 990. 正答率(テスト) = 0.7702
# Generation: 1000. 正答率(トレーニング) = 1.0
#                 : 1000. 正答率(テスト) = 0.7695

# %% [markdown]
# ## weight decay
# ### L2

# %%
from common import optimizer

(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]


network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)


iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10
hidden_layer_num = network.hidden_layer_num

# 正則化強度設定 ======================================
weight_decay_lambda = 0.0001
# =================================================

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    weight_decay = 0
    
    for idx in range(1, hidden_layer_num+1):
        grad['W' + str(idx)] = network.layers['Affine' + str(idx)].dW + weight_decay_lambda * network.params['W' + str(idx)]
        grad['b' + str(idx)] = network.layers['Affine' + str(idx)].db
        network.params['W' + str(idx)] -= learning_rate * grad['W' + str(idx)]
        network.params['b' + str(idx)] -= learning_rate * grad['b' + str(idx)]        
        weight_decay += 0.5 * weight_decay_lambda * np.sqrt(np.sum(network.params['W' + str(idx)] ** 2))

    loss = network.loss(x_batch, d_batch) + weight_decay
    train_loss_list.append(loss)        
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.15333333333333332
#                 : 10. 正答率(テスト) = 0.1341
# Generation: 20. 正答率(トレーニング) = 0.25333333333333335
#                 : 20. 正答率(テスト) = 0.1881
# Generation: 30. 正答率(トレーニング) = 0.3233333333333333
#                 : 30. 正答率(テスト) = 0.2438
# Generation: 40. 正答率(トレーニング) = 0.45
#                 : 40. 正答率(テスト) = 0.3199
# Generation: 50. 正答率(トレーニング) = 0.54
#                 : 50. 正答率(テスト) = 0.382
# Generation: 60. 正答率(トレーニング) = 0.5866666666666667
#                 : 60. 正答率(テスト) = 0.4491
# Generation: 70. 正答率(トレーニング) = 0.68
#                 : 70. 正答率(テスト) = 0.507
# Generation: 80. 正答率(トレーニング) = 0.7166666666666667
#                 : 80. 正答率(テスト) = 0.5491
# Generation: 90. 正答率(トレーニング) = 0.7566666666666667
#                 : 90. 正答率(テスト) = 0.5918
# Generation: 100. 正答率(トレーニング) = 0.7933333333333333
#                 : 100. 正答率(テスト) = 0.619
# Generation: 110. 正答率(トレーニング) = 0.8033333333333333
#                 : 110. 正答率(テスト) = 0.6344
# Generation: 120. 正答率(トレーニング) = 0.85
#                 : 120. 正答率(テスト) = 0.6542
# Generation: 130. 正答率(トレーニング) = 0.86
#                 : 130. 正答率(テスト) = 0.6652
# Generation: 140. 正答率(トレーニング) = 0.8766666666666667
#                 : 140. 正答率(テスト) = 0.677
# Generation: 150. 正答率(トレーニング) = 0.8866666666666667
#                 : 150. 正答率(テスト) = 0.6802
# Generation: 160. 正答率(トレーニング) = 0.8933333333333333
#                 : 160. 正答率(テスト) = 0.6927
# Generation: 170. 正答率(トレーニング) = 0.9033333333333333
#                 : 170. 正答率(テスト) = 0.6995
# Generation: 180. 正答率(トレーニング) = 0.9233333333333333
#                 : 180. 正答率(テスト) = 0.6996
# Generation: 190. 正答率(トレーニング) = 0.93
#                 : 190. 正答率(テスト) = 0.7115
# Generation: 200. 正答率(トレーニング) = 0.94
#                 : 200. 正答率(テスト) = 0.7135
# Generation: 210. 正答率(トレーニング) = 0.9333333333333333
#                 : 210. 正答率(テスト) = 0.7174
# Generation: 220. 正答率(トレーニング) = 0.9366666666666666
#                 : 220. 正答率(テスト) = 0.7263
# Generation: 230. 正答率(トレーニング) = 0.9466666666666667
#                 : 230. 正答率(テスト) = 0.7244
# Generation: 240. 正答率(トレーニング) = 0.9533333333333334
#                 : 240. 正答率(テスト) = 0.7326
# Generation: 250. 正答率(トレーニング) = 0.9566666666666667
#                 : 250. 正答率(テスト) = 0.7322
# Generation: 260. 正答率(トレーニング) = 0.96
#                 : 260. 正答率(テスト) = 0.7324
# Generation: 270. 正答率(トレーニング) = 0.9633333333333334
#                 : 270. 正答率(テスト) = 0.7365
# Generation: 280. 正答率(トレーニング) = 0.9666666666666667
#                 : 280. 正答率(テスト) = 0.7402
# Generation: 290. 正答率(トレーニング) = 0.9666666666666667
#                 : 290. 正答率(テスト) = 0.7409
# Generation: 300. 正答率(トレーニング) = 0.9666666666666667
#                 : 300. 正答率(テスト) = 0.7384
# Generation: 310. 正答率(トレーニング) = 0.97
#                 : 310. 正答率(テスト) = 0.7429
# Generation: 320. 正答率(トレーニング) = 0.97
#                 : 320. 正答率(テスト) = 0.7464
# Generation: 330. 正答率(トレーニング) = 0.9766666666666667
#                 : 330. 正答率(テスト) = 0.7478
# Generation: 340. 正答率(トレーニング) = 0.9766666666666667
#                 : 340. 正答率(テスト) = 0.748
# Generation: 350. 正答率(トレーニング) = 0.9833333333333333
#                 : 350. 正答率(テスト) = 0.7493
# Generation: 360. 正答率(トレーニング) = 0.98
#                 : 360. 正答率(テスト) = 0.7515
# Generation: 370. 正答率(トレーニング) = 0.9833333333333333
#                 : 370. 正答率(テスト) = 0.751
# Generation: 380. 正答率(トレーニング) = 0.99
#                 : 380. 正答率(テスト) = 0.7517
# Generation: 390. 正答率(トレーニング) = 0.9966666666666667
#                 : 390. 正答率(テスト) = 0.7567
# Generation: 400. 正答率(トレーニング) = 0.9966666666666667
#                 : 400. 正答率(テスト) = 0.7556
# Generation: 410. 正答率(トレーニング) = 0.9966666666666667
#                 : 410. 正答率(テスト) = 0.7566
# Generation: 420. 正答率(トレーニング) = 0.9966666666666667
#                 : 420. 正答率(テスト) = 0.7612
# Generation: 430. 正答率(トレーニング) = 0.9966666666666667
#                 : 430. 正答率(テスト) = 0.7598
# Generation: 440. 正答率(トレーニング) = 1.0
#                 : 440. 正答率(テスト) = 0.7635
# Generation: 450. 正答率(トレーニング) = 1.0
#                 : 450. 正答率(テスト) = 0.7632
# Generation: 460. 正答率(トレーニング) = 1.0
#                 : 460. 正答率(テスト) = 0.759
# Generation: 470. 正答率(トレーニング) = 1.0
#                 : 470. 正答率(テスト) = 0.7612
# Generation: 480. 正答率(トレーニング) = 1.0
#                 : 480. 正答率(テスト) = 0.7634
# Generation: 490. 正答率(トレーニング) = 1.0
#                 : 490. 正答率(テスト) = 0.7632
# Generation: 500. 正答率(トレーニング) = 1.0
#                 : 500. 正答率(テスト) = 0.7618
# Generation: 510. 正答率(トレーニング) = 1.0
#                 : 510. 正答率(テスト) = 0.7634
# Generation: 520. 正答率(トレーニング) = 1.0
#                 : 520. 正答率(テスト) = 0.7634
# Generation: 530. 正答率(トレーニング) = 1.0
#                 : 530. 正答率(テスト) = 0.7651
# Generation: 540. 正答率(トレーニング) = 1.0
#                 : 540. 正答率(テスト) = 0.7678
# Generation: 550. 正答率(トレーニング) = 1.0
#                 : 550. 正答率(テスト) = 0.7651
# Generation: 560. 正答率(トレーニング) = 1.0
#                 : 560. 正答率(テスト) = 0.7666
# Generation: 570. 正答率(トレーニング) = 1.0
#                 : 570. 正答率(テスト) = 0.7651
# Generation: 580. 正答率(トレーニング) = 1.0
#                 : 580. 正答率(テスト) = 0.7658
# Generation: 590. 正答率(トレーニング) = 1.0
#                 : 590. 正答率(テスト) = 0.7684
# Generation: 600. 正答率(トレーニング) = 1.0
#                 : 600. 正答率(テスト) = 0.7684
# Generation: 610. 正答率(トレーニング) = 1.0
#                 : 610. 正答率(テスト) = 0.7686
# Generation: 620. 正答率(トレーニング) = 1.0
#                 : 620. 正答率(テスト) = 0.7676
# Generation: 630. 正答率(トレーニング) = 1.0
#                 : 630. 正答率(テスト) = 0.7694
# Generation: 640. 正答率(トレーニング) = 1.0
#                 : 640. 正答率(テスト) = 0.7688
# Generation: 650. 正答率(トレーニング) = 1.0
#                 : 650. 正答率(テスト) = 0.7675
# Generation: 660. 正答率(トレーニング) = 1.0
#                 : 660. 正答率(テスト) = 0.7691
# Generation: 670. 正答率(トレーニング) = 1.0
#                 : 670. 正答率(テスト) = 0.7687
# Generation: 680. 正答率(トレーニング) = 1.0
#                 : 680. 正答率(テスト) = 0.769
# Generation: 690. 正答率(トレーニング) = 1.0
#                 : 690. 正答率(テスト) = 0.7703
# Generation: 700. 正答率(トレーニング) = 1.0
#                 : 700. 正答率(テスト) = 0.771
# Generation: 710. 正答率(トレーニング) = 1.0
#                 : 710. 正答率(テスト) = 0.7711
# Generation: 720. 正答率(トレーニング) = 1.0
#                 : 720. 正答率(テスト) = 0.7697
# Generation: 730. 正答率(トレーニング) = 1.0
#                 : 730. 正答率(テスト) = 0.7717
# Generation: 740. 正答率(トレーニング) = 1.0
#                 : 740. 正答率(テスト) = 0.7715
# Generation: 750. 正答率(トレーニング) = 1.0
#                 : 750. 正答率(テスト) = 0.7725
# Generation: 760. 正答率(トレーニング) = 1.0
#                 : 760. 正答率(テスト) = 0.7731
# Generation: 770. 正答率(トレーニング) = 1.0
#                 : 770. 正答率(テスト) = 0.7718
# Generation: 780. 正答率(トレーニング) = 1.0
#                 : 780. 正答率(テスト) = 0.7721
# Generation: 790. 正答率(トレーニング) = 1.0
#                 : 790. 正答率(テスト) = 0.7715
# Generation: 800. 正答率(トレーニング) = 1.0
#                 : 800. 正答率(テスト) = 0.7713
# Generation: 810. 正答率(トレーニング) = 1.0
#                 : 810. 正答率(テスト) = 0.7722
# Generation: 820. 正答率(トレーニング) = 1.0
#                 : 820. 正答率(テスト) = 0.7735
# Generation: 830. 正答率(トレーニング) = 1.0
#                 : 830. 正答率(テスト) = 0.7733
# Generation: 840. 正答率(トレーニング) = 1.0
#                 : 840. 正答率(テスト) = 0.7729
# Generation: 850. 正答率(トレーニング) = 1.0
#                 : 850. 正答率(テスト) = 0.773
# Generation: 860. 正答率(トレーニング) = 1.0
#                 : 860. 正答率(テスト) = 0.7731
# Generation: 870. 正答率(トレーニング) = 1.0
#                 : 870. 正答率(テスト) = 0.773
# Generation: 880. 正答率(トレーニング) = 1.0
#                 : 880. 正答率(テスト) = 0.7734
# Generation: 890. 正答率(トレーニング) = 1.0
#                 : 890. 正答率(テスト) = 0.7736
# Generation: 900. 正答率(トレーニング) = 1.0
#                 : 900. 正答率(テスト) = 0.7734
# Generation: 910. 正答率(トレーニング) = 1.0
#                 : 910. 正答率(テスト) = 0.7733
# Generation: 920. 正答率(トレーニング) = 1.0
#                 : 920. 正答率(テスト) = 0.773
# Generation: 930. 正答率(トレーニング) = 1.0
#                 : 930. 正答率(テスト) = 0.7746
# Generation: 940. 正答率(トレーニング) = 1.0
#                 : 940. 正答率(テスト) = 0.774
# Generation: 950. 正答率(トレーニング) = 1.0
#                 : 950. 正答率(テスト) = 0.7749
# Generation: 960. 正答率(トレーニング) = 1.0
#                 : 960. 正答率(テスト) = 0.7732
# Generation: 970. 正答率(トレーニング) = 1.0
#                 : 970. 正答率(テスト) = 0.7738
# Generation: 980. 正答率(トレーニング) = 1.0
#                 : 980. 正答率(テスト) = 0.7734
# Generation: 990. 正答率(トレーニング) = 1.0
#                 : 990. 正答率(テスト) = 0.7734
# Generation: 1000. 正答率(トレーニング) = 1.0
#                 : 1000. 正答率(テスト) = 0.7746

# %% [markdown]
# ### L1

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)


iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10
hidden_layer_num = network.hidden_layer_num

# 正則化強度設定 ======================================
weight_decay_lambda = 0.0001
# =================================================

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    weight_decay = 0
    
    for idx in range(1, hidden_layer_num+1):
        grad['W' + str(idx)] = network.layers['Affine' + str(idx)].dW + weight_decay_lambda * np.sign(network.params['W' + str(idx)])
        grad['b' + str(idx)] = network.layers['Affine' + str(idx)].db
        network.params['W' + str(idx)] -= learning_rate * grad['W' + str(idx)]
        network.params['b' + str(idx)] -= learning_rate * grad['b' + str(idx)]        
        weight_decay += weight_decay_lambda * np.sum(np.abs(network.params['W' + str(idx)]))

    loss = network.loss(x_batch, d_batch) + weight_decay
    train_loss_list.append(loss)        
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               
                
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.4066666666666667
#                 : 10. 正答率(テスト) = 0.3197
# Generation: 20. 正答率(トレーニング) = 0.7233333333333334
#                 : 20. 正答率(テスト) = 0.57
# Generation: 30. 正答率(トレーニング) = 0.8633333333333333
#                 : 30. 正答率(テスト) = 0.6896
# Generation: 40. 正答率(トレーニング) = 0.9
#                 : 40. 正答率(テスト) = 0.7082
# Generation: 50. 正答率(トレーニング) = 0.97
#                 : 50. 正答率(テスト) = 0.755
# Generation: 60. 正答率(トレーニング) = 0.9933333333333333
#                 : 60. 正答率(テスト) = 0.7838
# Generation: 70. 正答率(トレーニング) = 1.0
#                 : 70. 正答率(テスト) = 0.7867
# Generation: 80. 正答率(トレーニング) = 0.9966666666666667
#                 : 80. 正答率(テスト) = 0.7881
# Generation: 90. 正答率(トレーニング) = 1.0
#                 : 90. 正答率(テスト) = 0.7869
# Generation: 100. 正答率(トレーニング) = 1.0
#                 : 100. 正答率(テスト) = 0.7874
# Generation: 110. 正答率(トレーニング) = 1.0
#                 : 110. 正答率(テスト) = 0.7867
# Generation: 120. 正答率(トレーニング) = 1.0
#                 : 120. 正答率(テスト) = 0.787
# Generation: 130. 正答率(トレーニング) = 1.0
#                 : 130. 正答率(テスト) = 0.7872
# Generation: 140. 正答率(トレーニング) = 1.0
#                 : 140. 正答率(テスト) = 0.7879
# Generation: 150. 正答率(トレーニング) = 1.0
#                 : 150. 正答率(テスト) = 0.7885
# Generation: 160. 正答率(トレーニング) = 1.0
#                 : 160. 正答率(テスト) = 0.7869
# Generation: 170. 正答率(トレーニング) = 1.0
#                 : 170. 正答率(テスト) = 0.7865
# Generation: 180. 正答率(トレーニング) = 1.0
#                 : 180. 正答率(テスト) = 0.7887
# Generation: 190. 正答率(トレーニング) = 1.0
#                 : 190. 正答率(テスト) = 0.7876
# Generation: 200. 正答率(トレーニング) = 1.0
#                 : 200. 正答率(テスト) = 0.788
# Generation: 210. 正答率(トレーニング) = 1.0
#                 : 210. 正答率(テスト) = 0.788
# Generation: 220. 正答率(トレーニング) = 1.0
#                 : 220. 正答率(テスト) = 0.788
# Generation: 230. 正答率(トレーニング) = 1.0
#                 : 230. 正答率(テスト) = 0.7876
# Generation: 240. 正答率(トレーニング) = 1.0
#                 : 240. 正答率(テスト) = 0.788
# Generation: 250. 正答率(トレーニング) = 1.0
#                 : 250. 正答率(テスト) = 0.7886
# Generation: 260. 正答率(トレーニング) = 1.0
#                 : 260. 正答率(テスト) = 0.7888
# Generation: 270. 正答率(トレーニング) = 1.0
#                 : 270. 正答率(テスト) = 0.7889
# Generation: 280. 正答率(トレーニング) = 1.0
#                 : 280. 正答率(テスト) = 0.7892
# Generation: 290. 正答率(トレーニング) = 1.0
#                 : 290. 正答率(テスト) = 0.7892
# Generation: 300. 正答率(トレーニング) = 1.0
#                 : 300. 正答率(テスト) = 0.7879
# Generation: 310. 正答率(トレーニング) = 1.0
#                 : 310. 正答率(テスト) = 0.7892
# Generation: 320. 正答率(トレーニング) = 1.0
#                 : 320. 正答率(テスト) = 0.789
# Generation: 330. 正答率(トレーニング) = 1.0
#                 : 330. 正答率(テスト) = 0.7884
# Generation: 340. 正答率(トレーニング) = 1.0
#                 : 340. 正答率(テスト) = 0.7872
# Generation: 350. 正答率(トレーニング) = 1.0
#                 : 350. 正答率(テスト) = 0.7889
# Generation: 360. 正答率(トレーニング) = 1.0
#                 : 360. 正答率(テスト) = 0.7883
# Generation: 370. 正答率(トレーニング) = 1.0
#                 : 370. 正答率(テスト) = 0.7879
# Generation: 380. 正答率(トレーニング) = 1.0
#                 : 380. 正答率(テスト) = 0.7895
# Generation: 390. 正答率(トレーニング) = 1.0
#                 : 390. 正答率(テスト) = 0.7893
# Generation: 400. 正答率(トレーニング) = 1.0
#                 : 400. 正答率(テスト) = 0.7892
# Generation: 410. 正答率(トレーニング) = 1.0
#                 : 410. 正答率(テスト) = 0.7891
# Generation: 420. 正答率(トレーニング) = 1.0
#                 : 420. 正答率(テスト) = 0.7887
# Generation: 430. 正答率(トレーニング) = 1.0
#                 : 430. 正答率(テスト) = 0.7889
# Generation: 440. 正答率(トレーニング) = 1.0
#                 : 440. 正答率(テスト) = 0.7897
# Generation: 450. 正答率(トレーニング) = 1.0
#                 : 450. 正答率(テスト) = 0.7905
# Generation: 460. 正答率(トレーニング) = 1.0
#                 : 460. 正答率(テスト) = 0.7906
# Generation: 470. 正答率(トレーニング) = 1.0
#                 : 470. 正答率(テスト) = 0.7896
# Generation: 480. 正答率(トレーニング) = 1.0
#                 : 480. 正答率(テスト) = 0.7898
# Generation: 490. 正答率(トレーニング) = 1.0
#                 : 490. 正答率(テスト) = 0.7895
# Generation: 500. 正答率(トレーニング) = 1.0
#                 : 500. 正答率(テスト) = 0.789
# Generation: 510. 正答率(トレーニング) = 1.0
#                 : 510. 正答率(テスト) = 0.7906
# Generation: 520. 正答率(トレーニング) = 1.0
#                 : 520. 正答率(テスト) = 0.7898
# Generation: 530. 正答率(トレーニング) = 1.0
#                 : 530. 正答率(テスト) = 0.7901
# Generation: 540. 正答率(トレーニング) = 1.0
#                 : 540. 正答率(テスト) = 0.7904
# Generation: 550. 正答率(トレーニング) = 1.0
#                 : 550. 正答率(テスト) = 0.7904
# Generation: 560. 正答率(トレーニング) = 1.0
#                 : 560. 正答率(テスト) = 0.7909
# Generation: 570. 正答率(トレーニング) = 1.0
#                 : 570. 正答率(テスト) = 0.7898
# Generation: 580. 正答率(トレーニング) = 1.0
#                 : 580. 正答率(テスト) = 0.7903
# Generation: 590. 正答率(トレーニング) = 1.0
#                 : 590. 正答率(テスト) = 0.7907
# Generation: 600. 正答率(トレーニング) = 1.0
#                 : 600. 正答率(テスト) = 0.7906
# Generation: 610. 正答率(トレーニング) = 1.0
#                 : 610. 正答率(テスト) = 0.7919
# Generation: 620. 正答率(トレーニング) = 1.0
#                 : 620. 正答率(テスト) = 0.7913
# Generation: 630. 正答率(トレーニング) = 1.0
#                 : 630. 正答率(テスト) = 0.7907
# Generation: 640. 正答率(トレーニング) = 1.0
#                 : 640. 正答率(テスト) = 0.7908
# Generation: 650. 正答率(トレーニング) = 1.0
#                 : 650. 正答率(テスト) = 0.7906
# Generation: 660. 正答率(トレーニング) = 1.0
#                 : 660. 正答率(テスト) = 0.7912
# Generation: 670. 正答率(トレーニング) = 1.0
#                 : 670. 正答率(テスト) = 0.7913
# Generation: 680. 正答率(トレーニング) = 1.0
#                 : 680. 正答率(テスト) = 0.7902
# Generation: 690. 正答率(トレーニング) = 1.0
#                 : 690. 正答率(テスト) = 0.791
# Generation: 700. 正答率(トレーニング) = 1.0
#                 : 700. 正答率(テスト) = 0.7916
# Generation: 710. 正答率(トレーニング) = 1.0
#                 : 710. 正答率(テスト) = 0.7911
# Generation: 720. 正答率(トレーニング) = 1.0
#                 : 720. 正答率(テスト) = 0.7916
# Generation: 730. 正答率(トレーニング) = 1.0
#                 : 730. 正答率(テスト) = 0.7916
# Generation: 740. 正答率(トレーニング) = 1.0
#                 : 740. 正答率(テスト) = 0.7913
# Generation: 750. 正答率(トレーニング) = 1.0
#                 : 750. 正答率(テスト) = 0.7905
# Generation: 760. 正答率(トレーニング) = 1.0
#                 : 760. 正答率(テスト) = 0.7903
# Generation: 770. 正答率(トレーニング) = 1.0
#                 : 770. 正答率(テスト) = 0.7918
# Generation: 780. 正答率(トレーニング) = 1.0
#                 : 780. 正答率(テスト) = 0.7911
# Generation: 790. 正答率(トレーニング) = 1.0
#                 : 790. 正答率(テスト) = 0.7911
# Generation: 800. 正答率(トレーニング) = 1.0
#                 : 800. 正答率(テスト) = 0.7906
# Generation: 810. 正答率(トレーニング) = 1.0
#                 : 810. 正答率(テスト) = 0.7909
# Generation: 820. 正答率(トレーニング) = 1.0
#                 : 820. 正答率(テスト) = 0.7907
# Generation: 830. 正答率(トレーニング) = 1.0
#                 : 830. 正答率(テスト) = 0.7908
# Generation: 840. 正答率(トレーニング) = 1.0
#                 : 840. 正答率(テスト) = 0.7914
# Generation: 850. 正答率(トレーニング) = 1.0
#                 : 850. 正答率(テスト) = 0.7904
# Generation: 860. 正答率(トレーニング) = 1.0
#                 : 860. 正答率(テスト) = 0.7917
# Generation: 870. 正答率(トレーニング) = 1.0
#                 : 870. 正答率(テスト) = 0.7909
# Generation: 880. 正答率(トレーニング) = 1.0
#                 : 880. 正答率(テスト) = 0.7909
# Generation: 890. 正答率(トレーニング) = 1.0
#                 : 890. 正答率(テスト) = 0.7915
# Generation: 900. 正答率(トレーニング) = 1.0
#                 : 900. 正答率(テスト) = 0.7917
# Generation: 910. 正答率(トレーニング) = 1.0
#                 : 910. 正答率(テスト) = 0.791
# Generation: 920. 正答率(トレーニング) = 1.0
#                 : 920. 正答率(テスト) = 0.7912
# Generation: 930. 正答率(トレーニング) = 1.0
#                 : 930. 正答率(テスト) = 0.7905
# Generation: 940. 正答率(トレーニング) = 1.0
#                 : 940. 正答率(テスト) = 0.7914
# Generation: 950. 正答率(トレーニング) = 1.0
#                 : 950. 正答率(テスト) = 0.7912
# Generation: 960. 正答率(トレーニング) = 1.0
#                 : 960. 正答率(テスト) = 0.7906
# Generation: 970. 正答率(トレーニング) = 1.0
#                 : 970. 正答率(テスト) = 0.791
# Generation: 980. 正答率(トレーニング) = 1.0
#                 : 980. 正答率(テスト) = 0.7919
# Generation: 990. 正答率(トレーニング) = 1.0
#                 : 990. 正答率(テスト) = 0.7919
# Generation: 1000. 正答率(トレーニング) = 1.0
#                 : 1000. 正答率(テスト) = 0.7922

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------
# ## [try] weigth_decay_lambdaの値を変更して正則化の強さを確認しよう
# ----------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Dropout

# %%
class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None

    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)

    def backward(self, dout):
        return dout * self.mask

# %%
from common import optimizer
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

# ドロップアウト設定 ======================================
use_dropout = True
dropout_ratio = 0.15
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda, use_dropout = use_dropout, dropout_ratio = dropout_ratio)
# optimizer = optimizer.SGD(learning_rate=0.01)
# optimizer = optimizer.Momentum(learning_rate=0.01, momentum=0.9)
# optimizer = optimizer.AdaGrad(learning_rate=0.01)
optimizer = optimizer.Adam()

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)    
    
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.37333333333333335
#                 : 10. 正答率(テスト) = 0.2933
# Generation: 20. 正答率(トレーニング) = 0.5433333333333333
#                 : 20. 正答率(テスト) = 0.4388
# Generation: 30. 正答率(トレーニング) = 0.6333333333333333
#                 : 30. 正答率(テスト) = 0.5307
# Generation: 40. 正答率(トレーニング) = 0.7633333333333333
#                 : 40. 正答率(テスト) = 0.5913
# Generation: 50. 正答率(トレーニング) = 0.8533333333333334
#                 : 50. 正答率(テスト) = 0.6482
# Generation: 60. 正答率(トレーニング) = 0.8833333333333333
#                 : 60. 正答率(テスト) = 0.691
# Generation: 70. 正答率(トレーニング) = 0.9533333333333334
#                 : 70. 正答率(テスト) = 0.7294
# Generation: 80. 正答率(トレーニング) = 0.95
#                 : 80. 正答率(テスト) = 0.7397
# Generation: 90. 正答率(トレーニング) = 0.9866666666666667
#                 : 90. 正答率(テスト) = 0.7654
# Generation: 100. 正答率(トレーニング) = 0.9866666666666667
#                 : 100. 正答率(テスト) = 0.7679
# Generation: 110. 正答率(トレーニング) = 0.9966666666666667
#                 : 110. 正答率(テスト) = 0.7793
# Generation: 120. 正答率(トレーニング) = 0.9966666666666667
#                 : 120. 正答率(テスト) = 0.7889
# Generation: 130. 正答率(トレーニング) = 0.9966666666666667
#                 : 130. 正答率(テスト) = 0.7836
# Generation: 140. 正答率(トレーニング) = 1.0
#                 : 140. 正答率(テスト) = 0.7916
# Generation: 150. 正答率(トレーニング) = 1.0
#                 : 150. 正答率(テスト) = 0.7918
# Generation: 160. 正答率(トレーニング) = 1.0
#                 : 160. 正答率(テスト) = 0.8008
# Generation: 170. 正答率(トレーニング) = 1.0
#                 : 170. 正答率(テスト) = 0.7996
# Generation: 180. 正答率(トレーニング) = 1.0
#                 : 180. 正答率(テスト) = 0.7984
# Generation: 190. 正答率(トレーニング) = 1.0
#                 : 190. 正答率(テスト) = 0.798
# Generation: 200. 正答率(トレーニング) = 1.0
#                 : 200. 正答率(テスト) = 0.8015
# Generation: 210. 正答率(トレーニング) = 1.0
#                 : 210. 正答率(テスト) = 0.788
# Generation: 220. 正答率(トレーニング) = 1.0
#                 : 220. 正答率(テスト) = 0.7942
# Generation: 230. 正答率(トレーニング) = 1.0
#                 : 230. 正答率(テスト) = 0.8024
# Generation: 240. 正答率(トレーニング) = 1.0
#                 : 240. 正答率(テスト) = 0.8051
# Generation: 250. 正答率(トレーニング) = 1.0
#                 : 250. 正答率(テスト) = 0.797
# Generation: 260. 正答率(トレーニング) = 1.0
#                 : 260. 正答率(テスト) = 0.8001
# Generation: 270. 正答率(トレーニング) = 1.0
#                 : 270. 正答率(テスト) = 0.8052
# Generation: 280. 正答率(トレーニング) = 1.0
#                 : 280. 正答率(テスト) = 0.8058
# Generation: 290. 正答率(トレーニング) = 1.0
#                 : 290. 正答率(テスト) = 0.8095
# Generation: 300. 正答率(トレーニング) = 1.0
#                 : 300. 正答率(テスト) = 0.8088
# Generation: 310. 正答率(トレーニング) = 1.0
#                 : 310. 正答率(テスト) = 0.8108
# Generation: 320. 正答率(トレーニング) = 1.0
#                 : 320. 正答率(テスト) = 0.8093
# Generation: 330. 正答率(トレーニング) = 1.0
#                 : 330. 正答率(テスト) = 0.8116
# Generation: 340. 正答率(トレーニング) = 1.0
#                 : 340. 正答率(テスト) = 0.8097
# Generation: 350. 正答率(トレーニング) = 1.0
#                 : 350. 正答率(テスト) = 0.8065
# Generation: 360. 正答率(トレーニング) = 1.0
#                 : 360. 正答率(テスト) = 0.8101
# Generation: 370. 正答率(トレーニング) = 1.0
#                 : 370. 正答率(テスト) = 0.8115
# Generation: 380. 正答率(トレーニング) = 1.0
#                 : 380. 正答率(テスト) = 0.8006
# Generation: 390. 正答率(トレーニング) = 1.0
#                 : 390. 正答率(テスト) = 0.8144
# Generation: 400. 正答率(トレーニング) = 1.0
#                 : 400. 正答率(テスト) = 0.8049
# Generation: 410. 正答率(トレーニング) = 1.0
#                 : 410. 正答率(テスト) = 0.8041
# Generation: 420. 正答率(トレーニング) = 1.0
#                 : 420. 正答率(テスト) = 0.8123
# Generation: 430. 正答率(トレーニング) = 1.0
#                 : 430. 正答率(テスト) = 0.8137
# Generation: 440. 正答率(トレーニング) = 1.0
#                 : 440. 正答率(テスト) = 0.8208
# Generation: 450. 正答率(トレーニング) = 1.0
#                 : 450. 正答率(テスト) = 0.8196
# Generation: 460. 正答率(トレーニング) = 1.0
#                 : 460. 正答率(テスト) = 0.8028
# Generation: 470. 正答率(トレーニング) = 1.0
#                 : 470. 正答率(テスト) = 0.8102
# Generation: 480. 正答率(トレーニング) = 1.0
#                 : 480. 正答率(テスト) = 0.8141
# Generation: 490. 正答率(トレーニング) = 1.0
#                 : 490. 正答率(テスト) = 0.8119
# Generation: 500. 正答率(トレーニング) = 1.0
#                 : 500. 正答率(テスト) = 0.8097
# Generation: 510. 正答率(トレーニング) = 1.0
#                 : 510. 正答率(テスト) = 0.8088
# Generation: 520. 正答率(トレーニング) = 1.0
#                 : 520. 正答率(テスト) = 0.8149
# Generation: 530. 正答率(トレーニング) = 1.0
#                 : 530. 正答率(テスト) = 0.8183
# Generation: 540. 正答率(トレーニング) = 1.0
#                 : 540. 正答率(テスト) = 0.8136
# Generation: 550. 正答率(トレーニング) = 1.0
#                 : 550. 正答率(テスト) = 0.8101
# Generation: 560. 正答率(トレーニング) = 1.0
#                 : 560. 正答率(テスト) = 0.8093
# Generation: 570. 正答率(トレーニング) = 1.0
#                 : 570. 正答率(テスト) = 0.8067
# Generation: 580. 正答率(トレーニング) = 1.0
#                 : 580. 正答率(テスト) = 0.8093
# Generation: 590. 正答率(トレーニング) = 1.0
#                 : 590. 正答率(テスト) = 0.8083
# Generation: 600. 正答率(トレーニング) = 1.0
#                 : 600. 正答率(テスト) = 0.8021
# Generation: 610. 正答率(トレーニング) = 1.0
#                 : 610. 正答率(テスト) = 0.8001
# Generation: 620. 正答率(トレーニング) = 1.0
#                 : 620. 正答率(テスト) = 0.8025
# Generation: 630. 正答率(トレーニング) = 1.0
#                 : 630. 正答率(テスト) = 0.799
# Generation: 640. 正答率(トレーニング) = 1.0
#                 : 640. 正答率(テスト) = 0.8007
# Generation: 650. 正答率(トレーニング) = 1.0
#                 : 650. 正答率(テスト) = 0.7942
# Generation: 660. 正答率(トレーニング) = 1.0
#                 : 660. 正答率(テスト) = 0.8129
# Generation: 670. 正答率(トレーニング) = 1.0
#                 : 670. 正答率(テスト) = 0.8227
# Generation: 680. 正答率(トレーニング) = 1.0
#                 : 680. 正答率(テスト) = 0.82
# Generation: 690. 正答率(トレーニング) = 1.0
#                 : 690. 正答率(テスト) = 0.8171
# Generation: 700. 正答率(トレーニング) = 1.0
#                 : 700. 正答率(テスト) = 0.8159
# Generation: 710. 正答率(トレーニング) = 1.0
#                 : 710. 正答率(テスト) = 0.8171
# Generation: 720. 正答率(トレーニング) = 1.0
#                 : 720. 正答率(テスト) = 0.8145
# Generation: 730. 正答率(トレーニング) = 1.0
#                 : 730. 正答率(テスト) = 0.8198
# Generation: 740. 正答率(トレーニング) = 1.0
#                 : 740. 正答率(テスト) = 0.816
# Generation: 750. 正答率(トレーニング) = 1.0
#                 : 750. 正答率(テスト) = 0.803
# Generation: 760. 正答率(トレーニング) = 1.0
#                 : 760. 正答率(テスト) = 0.819
# Generation: 770. 正答率(トレーニング) = 1.0
#                 : 770. 正答率(テスト) = 0.8136
# Generation: 780. 正答率(トレーニング) = 1.0
#                 : 780. 正答率(テスト) = 0.8158
# Generation: 790. 正答率(トレーニング) = 1.0
#                 : 790. 正答率(テスト) = 0.8142
# Generation: 800. 正答率(トレーニング) = 1.0
#                 : 800. 正答率(テスト) = 0.8131
# Generation: 810. 正答率(トレーニング) = 1.0
#                 : 810. 正答率(テスト) = 0.8173
# Generation: 820. 正答率(トレーニング) = 1.0
#                 : 820. 正答率(テスト) = 0.8179
# Generation: 830. 正答率(トレーニング) = 1.0
#                 : 830. 正答率(テスト) = 0.8135
# Generation: 840. 正答率(トレーニング) = 1.0
#                 : 840. 正答率(テスト) = 0.8046
# Generation: 850. 正答率(トレーニング) = 1.0
#                 : 850. 正答率(テスト) = 0.8085
# Generation: 860. 正答率(トレーニング) = 1.0
#                 : 860. 正答率(テスト) = 0.8094
# Generation: 870. 正答率(トレーニング) = 1.0
#                 : 870. 正答率(テスト) = 0.8121
# Generation: 880. 正答率(トレーニング) = 1.0
#                 : 880. 正答率(テスト) = 0.819
# Generation: 890. 正答率(トレーニング) = 1.0
#                 : 890. 正答率(テスト) = 0.8161
# Generation: 900. 正答率(トレーニング) = 1.0
#                 : 900. 正答率(テスト) = 0.8161
# Generation: 910. 正答率(トレーニング) = 1.0
#                 : 910. 正答率(テスト) = 0.812
# Generation: 920. 正答率(トレーニング) = 1.0
#                 : 920. 正答率(テスト) = 0.799
# Generation: 930. 正答率(トレーニング) = 1.0
#                 : 930. 正答率(テスト) = 0.8157
# Generation: 940. 正答率(トレーニング) = 1.0
#                 : 940. 正答率(テスト) = 0.8211
# Generation: 950. 正答率(トレーニング) = 1.0
#                 : 950. 正答率(テスト) = 0.8144
# Generation: 960. 正答率(トレーニング) = 1.0
#                 : 960. 正答率(テスト) = 0.8038
# Generation: 970. 正答率(トレーニング) = 1.0
#                 : 970. 正答率(テスト) = 0.819
# Generation: 980. 正答率(トレーニング) = 1.0
#                 : 980. 正答率(テスト) = 0.8205
# Generation: 990. 正答率(トレーニング) = 1.0
#                 : 990. 正答率(テスト) = 0.8194
# Generation: 1000. 正答率(トレーニング) = 1.0
#                 : 1000. 正答率(テスト) = 0.8189

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] dropout_ratioの値を変更してみよう

# %% [markdown]
# ## [try] optimizerとdropout_ratioの値を変更してみよう
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Dropout + L1

# %%
from common import optimizer
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

# ドロップアウト設定 ======================================
use_dropout = True
dropout_ratio = 0.08
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        use_dropout = use_dropout, dropout_ratio = dropout_ratio)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []
hidden_layer_num = network.hidden_layer_num

plot_interval=10

# 正則化強度設定 ======================================
weight_decay_lambda=0.004
# =================================================

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    weight_decay = 0
    
    for idx in range(1, hidden_layer_num+1):
        grad['W' + str(idx)] = network.layers['Affine' + str(idx)].dW + weight_decay_lambda * np.sign(network.params['W' + str(idx)])
        grad['b' + str(idx)] = network.layers['Affine' + str(idx)].db
        network.params['W' + str(idx)] -= learning_rate * grad['W' + str(idx)]
        network.params['b' + str(idx)] -= learning_rate * grad['b' + str(idx)]        
        weight_decay += weight_decay_lambda * np.sum(np.abs(network.params['W' + str(idx)]))

    loss = network.loss(x_batch, d_batch) + weight_decay
    train_loss_list.append(loss)        
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.09666666666666666
#                 : 10. 正答率(テスト) = 0.0999
# Generation: 20. 正答率(トレーニング) = 0.13
#                 : 20. 正答率(テスト) = 0.1103
# Generation: 30. 正答率(トレーニング) = 0.14666666666666667
#                 : 30. 正答率(テスト) = 0.1224
# Generation: 40. 正答率(トレーニング) = 0.16333333333333333
#                 : 40. 正答率(テスト) = 0.133
# Generation: 50. 正答率(トレーニング) = 0.19666666666666666
#                 : 50. 正答率(テスト) = 0.1547
# Generation: 60. 正答率(トレーニング) = 0.22
#                 : 60. 正答率(テスト) = 0.1776
# Generation: 70. 正答率(トレーニング) = 0.25666666666666665
#                 : 70. 正答率(テスト) = 0.2201
# Generation: 80. 正答率(トレーニング) = 0.31333333333333335
#                 : 80. 正答率(テスト) = 0.2606
# Generation: 90. 正答率(トレーニング) = 0.33
#                 : 90. 正答率(テスト) = 0.2701
# Generation: 100. 正答率(トレーニング) = 0.3233333333333333
#                 : 100. 正答率(テスト) = 0.2719
# Generation: 110. 正答率(トレーニング) = 0.37333333333333335
#                 : 110. 正答率(テスト) = 0.291
# Generation: 120. 正答率(トレーニング) = 0.3933333333333333
#                 : 120. 正答率(テスト) = 0.3144
# Generation: 130. 正答率(トレーニング) = 0.42333333333333334
#                 : 130. 正答率(テスト) = 0.3262
# Generation: 140. 正答率(トレーニング) = 0.42333333333333334
#                 : 140. 正答率(テスト) = 0.3309
# Generation: 150. 正答率(トレーニング) = 0.42
#                 : 150. 正答率(テスト) = 0.3306
# Generation: 160. 正答率(トレーニング) = 0.44
#                 : 160. 正答率(テスト) = 0.3401
# Generation: 170. 正答率(トレーニング) = 0.43333333333333335
#                 : 170. 正答率(テスト) = 0.3451
# Generation: 180. 正答率(トレーニング) = 0.45666666666666667
#                 : 180. 正答率(テスト) = 0.3483
# Generation: 190. 正答率(トレーニング) = 0.4633333333333333
#                 : 190. 正答率(テスト) = 0.37
# Generation: 200. 正答率(トレーニング) = 0.48333333333333334
#                 : 200. 正答率(テスト) = 0.3794
# Generation: 210. 正答率(トレーニング) = 0.49666666666666665
#                 : 210. 正答率(テスト) = 0.3952
# Generation: 220. 正答率(トレーニング) = 0.5066666666666667
#                 : 220. 正答率(テスト) = 0.4085
# Generation: 230. 正答率(トレーニング) = 0.5133333333333333
#                 : 230. 正答率(テスト) = 0.4143
# Generation: 240. 正答率(トレーニング) = 0.52
#                 : 240. 正答率(テスト) = 0.422
# Generation: 250. 正答率(トレーニング) = 0.53
#                 : 250. 正答率(テスト) = 0.4297
# Generation: 260. 正答率(トレーニング) = 0.5366666666666666
#                 : 260. 正答率(テスト) = 0.4444
# Generation: 270. 正答率(トレーニング) = 0.5433333333333333
#                 : 270. 正答率(テスト) = 0.4451
# Generation: 280. 正答率(トレーニング) = 0.55
#                 : 280. 正答率(テスト) = 0.4561
# Generation: 290. 正答率(トレーニング) = 0.5833333333333334
#                 : 290. 正答率(テスト) = 0.4741
# Generation: 300. 正答率(トレーニング) = 0.6
#                 : 300. 正答率(テスト) = 0.4784
# Generation: 310. 正答率(トレーニング) = 0.61
#                 : 310. 正答率(テスト) = 0.4948
# Generation: 320. 正答率(トレーニング) = 0.6133333333333333
#                 : 320. 正答率(テスト) = 0.5099
# Generation: 330. 正答率(トレーニング) = 0.6266666666666667
#                 : 330. 正答率(テスト) = 0.5135
# Generation: 340. 正答率(トレーニング) = 0.6266666666666667
#                 : 340. 正答率(テスト) = 0.5171
# Generation: 350. 正答率(トレーニング) = 0.67
#                 : 350. 正答率(テスト) = 0.5265
# Generation: 360. 正答率(トレーニング) = 0.69
#                 : 360. 正答率(テスト) = 0.55
# Generation: 370. 正答率(トレーニング) = 0.69
#                 : 370. 正答率(テスト) = 0.5473
# Generation: 380. 正答率(トレーニング) = 0.7233333333333334
#                 : 380. 正答率(テスト) = 0.5665
# Generation: 390. 正答率(トレーニング) = 0.7566666666666667
#                 : 390. 正答率(テスト) = 0.5823
# Generation: 400. 正答率(トレーニング) = 0.7433333333333333
#                 : 400. 正答率(テスト) = 0.5842
# Generation: 410. 正答率(トレーニング) = 0.7533333333333333
#                 : 410. 正答率(テスト) = 0.595
# Generation: 420. 正答率(トレーニング) = 0.75
#                 : 420. 正答率(テスト) = 0.5964
# Generation: 430. 正答率(トレーニング) = 0.76
#                 : 430. 正答率(テスト) = 0.6053
# Generation: 440. 正答率(トレーニング) = 0.77
#                 : 440. 正答率(テスト) = 0.6152
# Generation: 450. 正答率(トレーニング) = 0.7766666666666666
#                 : 450. 正答率(テスト) = 0.6128
# Generation: 460. 正答率(トレーニング) = 0.7633333333333333
#                 : 460. 正答率(テスト) = 0.6155
# Generation: 470. 正答率(トレーニング) = 0.7766666666666666
#                 : 470. 正答率(テスト) = 0.6206
# Generation: 480. 正答率(トレーニング) = 0.78
#                 : 480. 正答率(テスト) = 0.6244
# Generation: 490. 正答率(トレーニング) = 0.78
#                 : 490. 正答率(テスト) = 0.619
# Generation: 500. 正答率(トレーニング) = 0.7833333333333333
#                 : 500. 正答率(テスト) = 0.6267
# Generation: 510. 正答率(トレーニング) = 0.79
#                 : 510. 正答率(テスト) = 0.6325
# Generation: 520. 正答率(トレーニング) = 0.7966666666666666
#                 : 520. 正答率(テスト) = 0.6379
# Generation: 530. 正答率(トレーニング) = 0.8
#                 : 530. 正答率(テスト) = 0.639
# Generation: 540. 正答率(トレーニング) = 0.7933333333333333
#                 : 540. 正答率(テスト) = 0.6416
# Generation: 550. 正答率(トレーニング) = 0.8
#                 : 550. 正答率(テスト) = 0.6438
# Generation: 560. 正答率(トレーニング) = 0.81
#                 : 560. 正答率(テスト) = 0.6456
# Generation: 570. 正答率(トレーニング) = 0.8266666666666667
#                 : 570. 正答率(テスト) = 0.6514
# Generation: 580. 正答率(トレーニング) = 0.8333333333333334
#                 : 580. 正答率(テスト) = 0.6611
# Generation: 590. 正答率(トレーニング) = 0.82
#                 : 590. 正答率(テスト) = 0.6548
# Generation: 600. 正答率(トレーニング) = 0.8333333333333334
#                 : 600. 正答率(テスト) = 0.6584
# Generation: 610. 正答率(トレーニング) = 0.8233333333333334
#                 : 610. 正答率(テスト) = 0.6608
# Generation: 620. 正答率(トレーニング) = 0.8366666666666667
#                 : 620. 正答率(テスト) = 0.6632
# Generation: 630. 正答率(トレーニング) = 0.84
#                 : 630. 正答率(テスト) = 0.6643
# Generation: 640. 正答率(トレーニング) = 0.8333333333333334
#                 : 640. 正答率(テスト) = 0.671
# Generation: 650. 正答率(トレーニング) = 0.8466666666666667
#                 : 650. 正答率(テスト) = 0.6754
# Generation: 660. 正答率(トレーニング) = 0.8433333333333334
#                 : 660. 正答率(テスト) = 0.6741
# Generation: 670. 正答率(トレーニング) = 0.8533333333333334
#                 : 670. 正答率(テスト) = 0.6746
# Generation: 680. 正答率(トレーニング) = 0.8566666666666667
#                 : 680. 正答率(テスト) = 0.6832
# Generation: 690. 正答率(トレーニング) = 0.86
#                 : 690. 正答率(テスト) = 0.6813
# Generation: 700. 正答率(トレーニング) = 0.8733333333333333
#                 : 700. 正答率(テスト) = 0.6847
# Generation: 710. 正答率(トレーニング) = 0.8633333333333333
#                 : 710. 正答率(テスト) = 0.6837
# Generation: 720. 正答率(トレーニング) = 0.8666666666666667
#                 : 720. 正答率(テスト) = 0.6893
# Generation: 730. 正答率(トレーニング) = 0.88
#                 : 730. 正答率(テスト) = 0.6799
# Generation: 740. 正答率(トレーニング) = 0.89
#                 : 740. 正答率(テスト) = 0.6886
# Generation: 750. 正答率(トレーニング) = 0.8833333333333333
#                 : 750. 正答率(テスト) = 0.6868
# Generation: 760. 正答率(トレーニング) = 0.89
#                 : 760. 正答率(テスト) = 0.6903
# Generation: 770. 正答率(トレーニング) = 0.8966666666666666
#                 : 770. 正答率(テスト) = 0.6998
# Generation: 780. 正答率(トレーニング) = 0.8866666666666667
#                 : 780. 正答率(テスト) = 0.6959
# Generation: 790. 正答率(トレーニング) = 0.9066666666666666
#                 : 790. 正答率(テスト) = 0.6972
# Generation: 800. 正答率(トレーニング) = 0.9
#                 : 800. 正答率(テスト) = 0.6982
# Generation: 810. 正答率(トレーニング) = 0.9133333333333333
#                 : 810. 正答率(テスト) = 0.7036
# Generation: 820. 正答率(トレーニング) = 0.9
#                 : 820. 正答率(テスト) = 0.6994
# Generation: 830. 正答率(トレーニング) = 0.91
#                 : 830. 正答率(テスト) = 0.7012
# Generation: 840. 正答率(トレーニング) = 0.9066666666666666
#                 : 840. 正答率(テスト) = 0.7036
# Generation: 850. 正答率(トレーニング) = 0.9133333333333333
#                 : 850. 正答率(テスト) = 0.6981
# Generation: 860. 正答率(トレーニング) = 0.92
#                 : 860. 正答率(テスト) = 0.7009
# Generation: 870. 正答率(トレーニング) = 0.92
#                 : 870. 正答率(テスト) = 0.7022
# Generation: 880. 正答率(トレーニング) = 0.9233333333333333
#                 : 880. 正答率(テスト) = 0.704
# Generation: 890. 正答率(トレーニング) = 0.9233333333333333
#                 : 890. 正答率(テスト) = 0.7119
# Generation: 900. 正答率(トレーニング) = 0.9233333333333333
#                 : 900. 正答率(テスト) = 0.7098
# Generation: 910. 正答率(トレーニング) = 0.92
#                 : 910. 正答率(テスト) = 0.7064
# Generation: 920. 正答率(トレーニング) = 0.9266666666666666
#                 : 920. 正答率(テスト) = 0.7115
# Generation: 930. 正答率(トレーニング) = 0.9266666666666666
#                 : 930. 正答率(テスト) = 0.7098
# Generation: 940. 正答率(トレーニング) = 0.9233333333333333
#                 : 940. 正答率(テスト) = 0.7107
# Generation: 950. 正答率(トレーニング) = 0.9333333333333333
#                 : 950. 正答率(テスト) = 0.7179
# Generation: 960. 正答率(トレーニング) = 0.9333333333333333
#                 : 960. 正答率(テスト) = 0.7178
# Generation: 970. 正答率(トレーニング) = 0.9366666666666666
#                 : 970. 正答率(テスト) = 0.7157
# Generation: 980. 正答率(トレーニング) = 0.93
#                 : 980. 正答率(テスト) = 0.7148
# Generation: 990. 正答率(トレーニング) = 0.9333333333333333
#                 : 990. 正答率(テスト) = 0.7162
# Generation: 1000. 正答率(トレーニング) = 0.9366666666666666
#                 : 1000. 正答率(テスト) = 0.7186
